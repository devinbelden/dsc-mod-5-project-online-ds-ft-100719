# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)
    
keys = get_keys("C:/Users/Devin/.secret/lichess_api.json")

api_key = keys['api_key']

# %%
team = "cheater-investigation-associationcia"

# %%
#!pip install -U fsds_100719

from fsds_100719.imports import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2c0cfbbfd9fd> in <module>
#       1 #!pip install -U fsds_100719
#       2
# ----> 3 from fsds_100719.imports import *
#
# ModuleNotFoundError: No module named 'fsds_100719'

# %%
import inspect

print(inspect.getsource(berserk.Client))

print(inspect.getsource(OAuth2Session))
# Out:
# class Client(BaseClient):
#     """Main touchpoint for the API.
#
#     All endpoints are namespaced into the clients below:
#
#     - :class:`account <berserk.clients.Account>` - managing account information
#     - :class:`bots <berserk.clients.Bots>` - performing bot operations
#     - :class:`broadcasts <berserk.clients.Broadcasts>` - getting and creating
#       broadcasts
#     - :class:`challenges <berserk.clients.Challenges>` - using challenges
#     - :class:`games <berserk.clients.Games>` - getting and exporting games
#     - :class:`simuls <berserk.clients.Simuls>` - getting simultaneous
#       exhibition games
#     - :class:`studies <berserk.clients.Studies>` - exporting studies
#     - :class:`teams <berserk.clients.Teams>` - getting information about teams
#     - :class:`tournaments <berserk.clients.Tournaments>` - getting and
#       creating tournaments
#     - :class:`users <berserk.clients.Users>` - getting information about users
#
# ...

# %%
from requests_oauthlib import OAuth2Session

session = OAuth2Session()
session.fetch_url(token_url='https://lichess.org')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9eb57869cfe7> in <module>
#       2
#       3 session = OAuth2Session()
# ----> 4 session.fetch_url(token_url='https://lichess.org')
#
# AttributeError: 'OAuth2Session' object has no attribute 'fetch_url'

# %%
import berserk

session = berserk.TokenSession(api_key)
client = berserk.Client(session=session)
help(client)
# Out:
# Help on Client in module berserk.clients object:
#
# class Client(BaseClient)
#  |  Main touchpoint for the API.
#  |
#  |  All endpoints are namespaced into the clients below:
#  |
#  |  - :class:`account <berserk.clients.Account>` - managing account information
#  |  - :class:`bots <berserk.clients.Bots>` - performing bot operations
#  |  - :class:`broadcasts <berserk.clients.Broadcasts>` - getting and creating
#  |    broadcasts
#  |  - :class:`challenges <berserk.clients.Challenges>` - using challenges
#  |  - :class:`games <berserk.clients.Games>` - getting and exporting games
#  |  - :class:`simuls <berserk.clients.Simuls>` - getting simultaneous
#  |    exhibition games
#  |  - :class:`studies <berserk.clients.Studies>` - exporting studies
#  |  - :class:`teams <berserk.clients.Teams>` - getting information about teams
#  |  - :class:`tournaments <berserk.clients.Tournaments>` - getting and
#  |    creating tournaments
# ...

# %%
members = list(client.users.get_by_team(team))
# Out:
# C:\Users\Devin\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated method get_by_team. (use Teams.get_members(id) instead) -- Deprecated since version 0.7.0.
#   """Entry point for launching an IPython kernel.

# %%
len(members)
# Out:
# 2619

# %%
members[1]
# Out:
# {'id': 'aconologia',
#  'username': 'Aconologia',
#  'online': False,
#  'perfs': {'blitz': {'games': 317, 'rating': 1270, 'rd': 45, 'prog': 7},
#   'puzzle': {'games': 134, 'rating': 1635, 'rd': 62, 'prog': -23},
#   'bullet': {'games': 275, 'rating': 1140, 'rd': 45, 'prog': -8},
#   'correspondence': {'games': 0,
#    'rating': 1500,
#    'rd': 350,
#    'prog': 0,
#    'prov': True},
#   'classical': {'games': 2,
#    'rating': 1568,
#    'rd': 214,
#    'prog': 0,
#    'prov': True},
#   'rapid': {'games': 154, 'rating': 1527, 'rd': 61, 'prog': 62}},
#  'createdAt': datetime.datetime(2019, 8, 22, 5, 47, 35, 543000, tzinfo=datetime.timezone.utc),
#  'seenAt': datetime.datetime(2020, 1, 27, 3, 32, 9, 86000, tzinfo=datetime.timezone.utc),
#  'playTime': {'total': 245659, 'tv': 740},
#  'url': 'https://lichess.org/@/Aconologia'}

# %%
for member in members[:5]:
    total_games = 0
    for game in game_types:
        total_games += member['perfs'][game]['games']
    print(total_games)
# Out:
# 0
# 748
# 978
# 156
# 0

# %%
active_members = []

game_types = ['blitz','bullet','classical','rapid']

for member in members:
    total_games = 0
    for game in game_types:
        total_games += member['perfs'][game]['games']
    if total_games > 500:
        active_members.append(member['id'])

active_members[:5]
# Out:
# ['aconologia', 'josyb', 'rooksknightmare', 'stourkwn', 'kcross12']

# %%
len(active_members)
# Out:
# 1550
